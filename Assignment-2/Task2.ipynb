# %% [markdown]
# # Практическая работа 2
# ## Задание
# 1. Создать SFrame на основе файла с тестовыми данными people-example.csv.
# 1. Используя функцию numpy.random.randint() создать новый столбец “Номер дома” с псевдо-случайными значениями в диапазоне [1, 150).
# 1. Создать новый столбец “ФИО”, который объединял бы значения столбцов “Имя” и “Фамилия”.
# 1. Используя логический фильтр, вывести все строки, в которых:
#     - 'ФИО' = 'Семен Семенов' ИЛИ 'Страна' = 'США'
#     - И 'Возраст' != 24
# 1. Вывести количество полученных записей для пункта 4.
# 1. Добавить вторую практическую работу в свой репозиторий.
# 1. В качестве результата выполненной практической работы выслать при завершении задания ссылку на Ваш GitHub репозиторий.

# %% [markdown]
# ### 1. Создать SFrame на основе файла с тестовыми данными people-example.csv.

# %%
import graphlab
sf = graphlab.SFrame('people-example.csv')
sf
# Out:
# Finished parsing file C:\Users\SaLLIoK\ML ONPU\Assignment-2\people-example.csv
# Parsing completed. Parsed 56 lines in 0.016023 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,str,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file C:\Users\SaLLIoK\ML ONPU\Assignment-2\people-example.csv
# Parsing completed. Parsed 56 lines in 0.01352 secs.
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
#
# Rows: 56
#
# Data:
# +-----------+-----------+-----------+---------+---------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст |
# +-----------+-----------+-----------+---------+---------+
# |   Семен   |  Мельник  |   Чикаго  |   США   |    24   |
# ...

# %% [markdown]
# ### 2. Используя функцию numpy.random.randint() создать новый столбец “Номер дома” с псевдо-случайными значениями в диапазоне [1, 150).

# %%
import numpy as np
sf['Номер дома'] = np.random.randint(1, 150, size=sf.num_rows())

# %% [markdown]
# ### 3. Создать новый столбец “ФИО”, который объединял бы значения столбцов “Имя” и “Фамилия”.

# %%
sf['ФИО'] = sf['Имя'] + ' ' + sf['Фамилия']
sf
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
# 	ФИО	str
#
# Rows: 56
#
# Data:
# +-----------+-----------+-----------+---------+---------+------------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст | Номер дома |
# +-----------+-----------+-----------+---------+---------+------------+
# |   Семен   |  Мельник  |   Чикаго  |   США   |    24   |     38     |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |     32     |
# | Екатерина | Коваленко | Манчестер |  Англия |    45   |    140     |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |    103     |
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |    137     |
# |   София   | Коваленко |    Киев   | Украина |    22   |     94     |
# |  Николай  |  Семенов  | Стокгольм |  Швеция |    25   |    117     |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |     30     |
# ...

# %% [markdown]
# ### 4. Используя логический фильтр, вывести все строки, в которых:
# #### a. 'ФИО' = 'Семен Семенов' ИЛИ 'Страна' = 'США'

# %%
sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США')]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
# 	ФИО	str
#
# Rows: Unknown
#
# Data:
# +-----------+---------+-----------+--------+---------+------------+
# |    Имя    | Фамилия |   Город   | Страна | Возраст | Номер дома |
# +-----------+---------+-----------+--------+---------+------------+
# |   Семен   | Мельник |   Чикаго  |  США   |    24   |     78     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    118     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |     53     |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |     67     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |     30     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |     7      |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |     44     |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |     80     |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |     90     |
# ...

# %% [markdown]
# #### b. И 'Возраст' != 24

# %%
sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США') & (sf['Возраст'] != 24)]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	Номер дома	int
# 	ФИО	str
#
# Rows: Unknown
#
# Data:
# +-----------+---------+-----------+--------+---------+------------+
# |    Имя    | Фамилия |   Город   | Страна | Возраст | Номер дома |
# +-----------+---------+-----------+--------+---------+------------+
# | Александр |  Шевчук | Вашингтон |  США   |    23   |    118     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |     53     |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |     67     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |     30     |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |     7      |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |     44     |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |     80     |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |     90     |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |     21     |
# ...

# %% [markdown]
# ### 5. Вывести количество полученных записей для пункта 4.

# %%
sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США') & (sf['Возраст'] != 24)].num_rows()
# Out:
# 15
